# %% [markdown]
#  # Business Understanding

# %% [markdown]
# In this study, we investigated the factors that impact the cost of a house in King's County. We studied these features, created and evaluated models that could estimate the price of the property.

# %% [markdown]
# ### Questions we can answer from these dataset

# %% [markdown]
# 1. How much can a stakeholder in King County offer for their homes?
# 2. How do I maximise the return of the real estate for the people in King County?
# 3. Factors that a higher effect on the price in the King County?

# %% [markdown]
# Column Names and descriptions for Kings County Data Set
# * **id** - unique identified for a house
# * **dateDate** - house was sold
# * **pricePrice** -  is prediction target
# * **bedroomsNumber** -  of Bedrooms/House
# * **bathroomsNumber** -  of bathrooms/bedrooms
# * **sqft_livingsquare** -  footage of the home
# * **sqft_lotsquare** -  footage of the lot
# * **floorsTotal** -  floors (levels) in house
# * **waterfront** - House which has a view to a waterfront
# * **view** - Has been viewed
# * **condition** - How good the condition is ( Overall )
# * **grade** - overall grade given to the housing unit, based on King County grading system
# * **sqft_above** - square footage of house apart from basement
# * **sqft_basement** - square footage of the basement
# * **yr_built** - Built Year
# * **yr_renovated** - Year when house was renovated
# * **zipcode** - zip
# * **lat** - Latitude coordinate
# * **long** - Longitude coordinate
# * **sqft_living15** - The square footage of interior housing living space for the nearest 15 neighbors
# * **sqft_lot15** - The square footage of the land lots of the nearest 15 neighbors

# %%
#importing necessary analysis libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import statsmodels.api as sm

# %%
# import libraries
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats
import statsmodels.stats.api as sms

# %%
#Loading orginal dataframe
df = pd.read_csv('Data\kc_house_data.csv')
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 0          5650     1.0         NaN   0.0  ...      7        1180
# 1          7242     2.0         0.0   0.0  ...      7        2170
# 2         10000     1.0         0.0   0.0  ...      6         770
# 3          5000     1.0         0.0   0.0  ...      7        1050
# 4          8080     1.0         0.0   0.0  ...      8        1680
# ...         ...     ...         ...   ...  ...    ...         ...
# 21592      1131     3.0         0.0   0.0  ...      8        1530
# 21593      5813     2.0         0.0   0.0  ...      8        2310
# 21594      1350     2.0         0.0   0.0  ...      7        1020
# 21595      2388     2.0         NaN   0.0  ...      8        1600
# 21596      1076     2.0         0.0   0.0  ...      7        1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 0                0.0     1955           0.0    98178  47.5112 -122.257
# 1              400.0     1951        1991.0    98125  47.7210 -122.319
# 2                0.0     1933           NaN    98028  47.7379 -122.233
# 3              910.0     1965           0.0    98136  47.5208 -122.393
# 4                0.0     1987           0.0    98074  47.6168 -122.045
# ...              ...      ...           ...      ...      ...      ...
# 21592            0.0     2009           0.0    98103  47.6993 -122.346
# 21593            0.0     2014           0.0    98146  47.5107 -122.362
# 21594            0.0     2009           0.0    98144  47.5944 -122.299
# 21595            0.0     2004           0.0    98027  47.5345 -122.069
# 21596            0.0     2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 1               1690        7639
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# ...              ...         ...
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21595           1410        1287
# 21596           1020        1357
#
# [21597 rows x 21 columns]

# %%
#Viewing columns
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#overview of the data and it data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
#Converting dates into datetime objects for easy manipulation
df['date'] = pd.to_datetime(df['date'])

# %%
#dealing with missing data
df.isnull().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
#Checking for deplicates
df.duplicated().value_counts()
# Out:
# False    21597
# dtype: int64

# %%
df['price']
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21592    360000.0
# 21593    400000.0
# 21594    402101.0
# 21595    400000.0
# 21596    325000.0
# Name: price, Length: 21597, dtype: float64

# %%
#Creating a dataframe with only the position coordinates for home in the data
location_data = df[['price','lat','long']]
location_data.head()
# Out:
#       price      lat     long
# 0  221900.0  47.5112 -122.257
# 1  538000.0  47.7210 -122.319
# 2  180000.0  47.7379 -122.233
# 3  604000.0  47.5208 -122.393
# 4  510000.0  47.6168 -122.045

# %%
location_data.to_excel(r'Data\lcoation.xlsx', index=False)

# %%
#Creating dataframe for features I believe may be correlated with price
new_df = df[['price','bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'grade','condition','yr_built', 'yr_renovated']]
new_df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  grade  \
# 0      221900.0         3       1.00         1180      5650     1.0      7
# 1      538000.0         3       2.25         2570      7242     2.0      7
# 2      180000.0         2       1.00          770     10000     1.0      6
# 3      604000.0         4       3.00         1960      5000     1.0      7
# 4      510000.0         3       2.00         1680      8080     1.0      8
# ...         ...       ...        ...          ...       ...     ...    ...
# 21592  360000.0         3       2.50         1530      1131     3.0      8
# 21593  400000.0         4       2.50         2310      5813     2.0      8
# 21594  402101.0         2       0.75         1020      1350     2.0      7
# 21595  400000.0         3       2.50         1600      2388     2.0      8
# 21596  325000.0         2       0.75         1020      1076     2.0      7
#
#        condition  zipcode  yr_built  yr_renovated
# 0              3    98178      1955           0.0
# 1              3    98125      1951        1991.0
# 2              3    98028      1933           NaN
# 3              5    98136      1965           0.0
# 4              3    98074      1987           0.0
# ...          ...      ...       ...           ...
# 21592          3    98103      2009           0.0
# 21593          3    98146      2014           0.0
# 21594          3    98144      2009           0.0
# 21595          3    98027      2004           0.0
# 21596          3    98144      2008           0.0
#
# [21597 rows x 11 columns]

# %%
new_df['zipcode'].nunique()
# Out:
# 70

# %%
new_df['condition'].unique()
# Out:
# array([3, 5, 4, 1, 2], dtype=int64)

# %%
new_df['grade'].unique()
# Out:
# array([ 7,  6,  8, 11,  9,  5, 10, 12,  4,  3, 13], dtype=int64)

# %%
## Checking for Normality

# %%
new_df.hist(figsize=(15,15));

# %% [markdown]
# # Assumptions of Linear Regression

# %% [markdown]
# ## Linear relationship

# %%
new_df.columns[1:]
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'grade',
#        'condition', 'zipcode', 'yr_built', 'yr_renovated'],
#       dtype='object')

# %%
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(16,15), sharey=True )

#simultaneously iterate through each column of data and through each of our axes making a plot for each step along the way
for ax, column in zip(axes.flatten(), new_df.columns[1:]):
    ax.scatter(new_df[column], new_df['price'], label=column, alpha=.1)
    ax.set_title(f'price vs {column}')
    ax.set_xlabel(column)
    ax.set_ylabel('Price')
fig.tight_layout()

# %%
new_df['renovation'] =  new_df['yr_renovated'].map(lambda x : 'not_renovated' if x == 0 else( 'renovated') ) 
new_df['renovation']
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_20388\296059280.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['renovation'] =  new_df['yr_renovated'].map(lambda x : 'not_renovated' if x == 0 else( 'renovated') )
# 0        not_renovated
# 1            renovated
# 2            renovated
# 3        not_renovated
# 4        not_renovated
#              ...
# 21592    not_renovated
# 21593    not_renovated
# 21594    not_renovated
# 21595    not_renovated
# 21596    not_renovated
# Name: renovation, Length: 21597, dtype: object

# %%
new_df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  grade  \
# 0      221900.0         3       1.00         1180      5650     1.0      7
# 1      538000.0         3       2.25         2570      7242     2.0      7
# 2      180000.0         2       1.00          770     10000     1.0      6
# 3      604000.0         4       3.00         1960      5000     1.0      7
# 4      510000.0         3       2.00         1680      8080     1.0      8
# ...         ...       ...        ...          ...       ...     ...    ...
# 21592  360000.0         3       2.50         1530      1131     3.0      8
# 21593  400000.0         4       2.50         2310      5813     2.0      8
# 21594  402101.0         2       0.75         1020      1350     2.0      7
# 21595  400000.0         3       2.50         1600      2388     2.0      8
# 21596  325000.0         2       0.75         1020      1076     2.0      7
#
#        condition  zipcode  yr_built  yr_renovated     renovation
# 0              3    98178      1955           0.0  not_renovated
# 1              3    98125      1951        1991.0      renovated
# 2              3    98028      1933           NaN      renovated
# 3              5    98136      1965           0.0  not_renovated
# 4              3    98074      1987           0.0  not_renovated
# ...          ...      ...       ...           ...            ...
# 21592          3    98103      2009           0.0  not_renovated
# 21593          3    98146      2014           0.0  not_renovated
# 21594          3    98144      2009           0.0  not_renovated
# 21595          3    98027      2004           0.0  not_renovated
# 21596          3    98144      2008           0.0  not_renovated
#
# [21597 rows x 12 columns]

# %% [markdown]
# ## Checking for corr()

# %%
pd.plotting.scatter_matrix(new_df,figsize=(15,15));

plt.show()

# %%
sns.pairplot(new_df);

# %%
new_df.corr()
# Out:
#                  price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price         1.000000  0.308787   0.525906     0.701917  0.089876  0.256804
# bedrooms      0.308787  1.000000   0.514508     0.578212  0.032471  0.177944
# bathrooms     0.525906  0.514508   1.000000     0.755758  0.088373  0.502582
# sqft_living   0.701917  0.578212   0.755758     1.000000  0.173453  0.353953
# sqft_lot      0.089876  0.032471   0.088373     0.173453  1.000000 -0.004814
# floors        0.256804  0.177944   0.502582     0.353953 -0.004814  1.000000
# grade         0.667951  0.356563   0.665838     0.762779  0.114731  0.458794
# condition     0.036056  0.026496  -0.126479    -0.059445 -0.008830 -0.264075
# zipcode      -0.053402 -0.154092  -0.204786    -0.199802 -0.129586 -0.059541
# yr_built      0.053953  0.155670   0.507173     0.318152  0.052946  0.489193
# yr_renovated  0.129599  0.018495   0.051050     0.055660  0.004513  0.003535
#
#                  grade  condition   zipcode  yr_built  yr_renovated
# price         0.667951   0.036056 -0.053402  0.053953      0.129599
# bedrooms      0.356563   0.026496 -0.154092  0.155670      0.018495
# bathrooms     0.665838  -0.126479 -0.204786  0.507173      0.051050
# sqft_living   0.762779  -0.059445 -0.199802  0.318152      0.055660
# sqft_lot      0.114731  -0.008830 -0.129586  0.052946      0.004513
# floors        0.458794  -0.264075 -0.059541  0.489193      0.003535
# grade         1.000000  -0.146896 -0.185771  0.447865      0.016669
# condition    -0.146896   1.000000  0.002888 -0.361592     -0.061858
# zipcode      -0.185771   0.002888  1.000000 -0.347210      0.069846
# yr_built      0.447865  -0.361592 -0.347210  1.000000     -0.225209
# yr_renovated  0.016669  -0.061858  0.069846 -0.225209      1.000000

# %%
fig, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(new_df.corr(), annot=True,cmap='Greens');
# Out:
# <AxesSubplot:>

# %%
abs(new_df.corr()) > 0.75
# Out:
#               price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# price          True     False      False        False     False   False
# bedrooms      False      True      False        False     False   False
# bathrooms     False     False       True         True     False   False
# sqft_living   False     False       True         True     False   False
# sqft_lot      False     False      False        False      True   False
# floors        False     False      False        False     False    True
# grade         False     False      False         True     False   False
# condition     False     False      False        False     False   False
# zipcode       False     False      False        False     False   False
# yr_built      False     False      False        False     False   False
# yr_renovated  False     False      False        False     False   False
#
#               grade  condition  zipcode  yr_built  yr_renovated
# price         False      False    False     False         False
# bedrooms      False      False    False     False         False
# bathrooms     False      False    False     False         False
# sqft_living    True      False    False     False         False
# sqft_lot      False      False    False     False         False
# floors        False      False    False     False         False
# grade          True      False    False     False         False
# condition     False       True    False     False         False
# zipcode       False      False     True     False         False
# yr_built      False      False    False      True         False
# yr_renovated  False      False    False     False          True

# %%
df = new_df.corr().abs().stack().reset_index().sort_values(0, ascending=False)

df['pairs'] = list(zip(df.level_0, df.level_1))

df.set_index(['pairs'], inplace = True)

df.drop(columns=['level_1', 'level_0'], inplace = True)

# cc for correlation coefficient
df.columns = ['cc']

df.drop_duplicates(inplace=True)

df[(df.cc>.75) & (df.cc<1)]
# Out:
#                                 cc
# pairs
# (grade, sqft_living)      0.762779
# (sqft_living, bathrooms)  0.755758

# %%
# Drop sqft_living

# %% [markdown]
# ## Modeling

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
main_y = new_df['price']
main_x = 

train1 =

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test =  train_test_split()
